# %% [markdown]
# <a href="https://colab.research.google.com/github/sudekaygisiz/RAG-Based-Chatbots/blob/main/Ders_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Gemini API Anahtarı Alma ve Kullanımı**
#
# ## Kullanmaya başlama adımları
#
#
#
# 1.   [Google AI Studio](https://aistudio.google.com)'ya gidip Google Hesabınızla giriş yapın.
# 2.   [API anahtarı](https://https://aistudio.google.com/app/api-keys) oluşturma.
# 3.   [Python](https://colab.research.google.com/github/google-gemini/cookbook/blob/main/quickstarts/Get_started.ipynb) hızlı başlangıç kılavuzunu kullanın veya [curl](https://colab.research.google.com/github/google-gemini/cookbook/blob/main/quickstarts/rest/Prompting_REST.ipynb) kullanarak REST API'yi çağırın.

# %%
from google.colab import userdata
api_key=userdata.get('GEMİNİ_API_KEY')

# %%
from google import genai

client = genai.Client(api_key=api_key)

response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents="Yapay zeka nedir?",
)

print(response.text)
# Out:
# Yapay zeka (YZ veya İngilizce'deki kısaltmasıyla AI - Artificial Intelligence), makinelerin insan benzeri zihinsel yetenekleri sergilemesini sağlamayı amaçlayan bilgisayar bilimlerinin bir dalıdır. Temel olarak, bilgisayar sistemlerinin verilerden öğrenmesini, akıl yürütmesini, problem çözmesini, algılamasını, dil anlamasını ve karar vermesini sağlamak için tasarlanmış algoritmalar ve modeller bütünüdür.
#
# **Yapay Zekanın Temel Amaçları ve Yetenekleri:**
#
# 1.  **Öğrenme (Machine Learning):** Makinelerin açıkça programlanmadan verilerden örüntüler çıkararak öğrenmesini ve zamanla performansını iyileştirmesini sağlar. Derin öğrenme (Deep Learning) ise bunun bir alt kümesidir ve insan beyninin çalışma şeklinden esinlenerek oluşturulmuş yapay sinir ağları kullanır.
# 2.  **Akıl Yürütme ve Problem Çözme:** Makinelerin karmaşık sorunları analiz etmesini, mantıksal çıkarımlar yapmasını ve çözümler üretmesini sağlar.
# 3.  **Algılama (Perception):** Görüntü işleme (bilgisayarlı görü) ile görselleri analiz etme, ses tanıma ile sesli komutları ve konuşmayı anlama yeteneği.
# 4.  **Dil Anlama ve Üretme (Natural Language Processing - NLP):** İnsan dilini anlama, yorumlama ve doğal dilde yanıt üretme yeteneği. Sohbet robotları (chatbots) ve çeviri sistemleri buna örnektir.
# 5.  **Karar Verme:** Belirli veriler ve koşullar altında en uygun kararı verme yeteneği.
#
# **Yapay Zeka Türleri:**
#
# Yapay zeka genellikle yetenek seviyesine göre üç ana kategoriye ayrılır:
#
# 1.  **Dar Yapay Zeka (Narrow AI / Weak AI):** Belirli ve tek bir görevi çok iyi yapabilen yapay zeka türüdür. Günümüzde karşılaştığımız tüm yapay zeka uygulamaları bu kategoriye girer.
#     *   **Örnekler:** Siri, Alexa gibi sesli asistanlar, otonom araçlar, öneri sistemleri (Netflix, Amazon), satranç oynayan bilgisayarlar, spam filtreleri.
# 2.  **Genel Yapay Zeka (General AI / Strong AI):** İnsan zekasının sahip olduğu tüm bilişsel yetenekleri (öğrenme, akıl yürütme, problem çözme vb.) farklı alanlarda sergileyebilen, teorik bir yapay zeka türüdür. Henüz bu seviyeye ulaşılmamıştır.
# 3.  **Süper Zeka (Superintelligence):** İnsan zekasının tüm yönlerini (yaratıcılık, sanat, sosyal beceriler dahil) önemli ölçüde aşan, daha da ileri bir teorik yapay zeka seviyesidir.
#
# **Yapay Zekanın Kullanım Alanları:**
#
# Yapay zeka, günümüzde birçok sektörde ve alanda hayatımızı dönüştürmektedir:
#
# *   **Sağlık:** Hastalıkların teşhisi, ilaç keşfi, kişiselleştirilmiş tedavi planları.
# *   **Finans:** Sahtekarlık tespiti, algoritmik ticaret, kredi risk analizi.
# *   **Otomotiv:** Sürücüsüz araçlar, sürüş destek sistemleri.
# *   **Eğitim:** Kişiselleştirilmiş öğrenme deneyimleri, akıllı ders materyalleri.
# *   **Üretim:** Robotik otomasyon, kalite kontrolü, tahmine dayalı bakım.
# *   **Müşteri Hizmetleri:** Sohbet robotları (chatbots), sanal asistanlar.
# *   **Eğlence:** Öneri sistemleri (filmler, müzikler), oyunlar.
# *   **Güvenlik:** Yüz tanıma, siber güvenlik tehdit tespiti.
#
# Yapay zeka, modern teknolojinin en hızlı gelişen ve en etkili alanlarından biridir. İnsanlığın karşılaştığı birçok zorluğun üstesinden gelme ve yaşam kalitemizi artırma potansiyeline sahiptir, ancak aynı zamanda etik, iş gücü ve gizlilik gibi konularda önemli tartışmaları da beraberinde getirmektedir.
