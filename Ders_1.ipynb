# %% [markdown]
# <a href="https://colab.research.google.com/github/sudekaygisiz/RAG-Based-Chatbots/blob/main/Ders_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Gemini API Anahtarı Alma ve Kullanımı**
#
# ## Kullanmaya başlama adımları
#
#
#
# 1.   [Google AI Studio](https://aistudio.google.com)'ya gidip Google Hesabınızla giriş yapın.
# 2.   [API anahtarı](https://https://aistudio.google.com/app/api-keys) oluşturma.
# 3.   [Python](https://colab.research.google.com/github/google-gemini/cookbook/blob/main/quickstarts/Get_started.ipynb) hızlı başlangıç kılavuzunu kullanın veya [curl](https://colab.research.google.com/github/google-gemini/cookbook/blob/main/quickstarts/rest/Prompting_REST.ipynb) kullanarak REST API'yi çağırın.

# %%
from google.colab import userdata
api_key=userdata.get('GEMİNİ_API_KEY')

# %%
from google import genai

client = genai.Client(api_key=api_key)

response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents="Yapay zeka nedir?",
)

print(response.text)
# Out:
# Yapay Zeka (YZ), bilgisayar bilimlerinin bir dalı olup, makinelerin insan benzeri zihinsel işlevleri taklit etmesini sağlayan bir teknolojidir. Temel amacı, makineleri öğrenme, akıl yürütme, problem çözme, algılama, dil anlama ve karar verme gibi insana özgü bilişsel yeteneklerle donatmaktır.
#
# Basitçe ifade etmek gerekirse, Yapay Zeka, bilgisayarların "düşünmesini" ve "öğrenmesini" sağlamak üzerinedir.
#
# **Yapay Zeka Neleri Amaçlar?**
#
# *   **Öğrenme:** Deneyimlerden ve verilerden bilgi edinme, kalıpları tanıma ve gelecekteki kararlar için bu bilgiyi kullanma yeteneği. (Örn: Makine Öğrenimi, Derin Öğrenme)
# *   **Akıl Yürütme ve Problem Çözme:** Mantık yürütme, problem senaryolarını anlama ve en iyi çözümleri bulma.
# *   **Algılama:** Görsel (bilgisayar görüşü) ve işitsel (konuşma tanıma) verileri işleyip anlama.
# *   **Doğal Dil İşleme (NLP):** İnsan dilini anlama, yorumlama ve üretme.
# *   **Karar Verme:** Belirli hedeflere ulaşmak için en uygun eylemi seçme.
# ...

# %%
# %pip install -U -q 'google-genai>=1.51.0'
